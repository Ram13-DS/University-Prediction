# %% [markdown]
# # Importing packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score,recall_score,f1_score,precision_score

# %% [markdown]
# # Data Loading and preprocessing

# %%
data=pd.read_excel("Survey on Universities.xlsx")
data.sample(5)
# Out:
#     Student ID               Timestamp         Student Name  \
# 47          48 2023-07-28 21:15:25.328  SRINIVAS MUKANAGAL
# 61          62 2023-07-29 08:07:13.043        TEJESHWARI. D
# 82          83 2023-08-01 14:32:39.973            SURENDRA
# 8            9 2023-07-28 11:32:48.136         SOMA SEKHAR
# 22          23 2023-07-28 19:05:10.564             K.ROHITH
#
#                                      University Name  NIRF Rank of University  \
# 47  NAGARJUNA  COLLEGE OF ENGINEERING AND TECHNOLOGY                      152
# 61  NAGARJUNA  COLLEGE OF ENGINEERING AND TECHNOLOGY                      152
# 82                                    YV UNIVERSITY                        80
# 8                                               AITS                       88
# 22                                   SRM UNIVERSITY                        35
#
#     Minimum Percentage to get the University seat Intermediate Percentage  \
# 47                                             60                Above 90
# 61                                             60                      70
# 82                                             50                      80
# 8                                              80                      80
# 22                                             75                      70
#
#     Eamcet Rank  University Fee How are the placements Available   \
# 47      12000.0          250000                              Good
# 61          NaN           40000                           Average
# 82       5839.0          600000                              Good
# 8      500000.0          400000                              Good
# 22          NaN          350000                              Good
#
#     Rating for your University  \
# 47                           1
# 61                           3
# 82                           4
# 8                            4
# 22                           5
#
#    Do Your University is having Extra curricular Activity   \
# 47                                                YES
# 61                                                YES
# 82                                                YES
# 8                                                  NO
# 22                                                YES
#
#    Do Your University is having Industry Evaluation Interaction  \
# 47                                                YES
# 61                                                 NO
# 82                                                YES
# 8                                                 YES
# 22                                                YES
#
#    Hostel Availability  Hostel Fee  Hostel food Rating
# 47                 YES    100000.0                   3
# 61                 YES    100000.0                   4
# 82                  NO         0.0                   4
# 8                  YES   5000000.0                   3
# 22                 YES    140000.0                   3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 16 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Student ID                                                    101 non-null    int64
#  1   Timestamp                                                     101 non-null    datetime64[ns]
#  2   Student Name                                                  101 non-null    object
#  3   University Name                                               101 non-null    object
#  4   NIRF Rank of University                                       101 non-null    int64
#  5   Minimum Percentage to get the University seat                 101 non-null    int64
#  6   Intermediate Percentage                                       101 non-null    object
#  7   Eamcet Rank                                                   66 non-null     float64
#  8   University Fee                                                101 non-null    int64
#  9   How are the placements Available                              101 non-null    object
#  10  Rating for your University                                    101 non-null    int64
#  11  Do Your University is having Extra curricular Activity        101 non-null    object
#  12  Do Your University is having Industry Evaluation Interaction  101 non-null    object
#  13  Hostel Availability                                           101 non-null    object
#  14  Hostel Fee                                                    95 non-null     float64
#  15  Hostel food Rating                                            101 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(6), object(7)
# memory usage: 12.8+ KB

# %%
data.isnull().sum()
# Out:
# Student ID                                                       0
# Timestamp                                                        0
# Student Name                                                     0
# University Name                                                  0
# NIRF Rank of University                                          0
# Minimum Percentage to get the University seat                    0
# Intermediate Percentage                                          0
# Eamcet Rank                                                     35
# University Fee                                                   0
# How are the placements Available                                 0
# Rating for your University                                       0
# Do Your University is having Extra curricular Activity           0
# Do Your University is having Industry Evaluation Interaction     0
# Hostel Availability                                              0
# Hostel Fee                                                       6
# Hostel food Rating                                               0
# dtype: int64

# %%
data['Eamcet Rank']=data['Eamcet Rank'].fillna(data['Eamcet Rank'].median())
data['Hostel Fee']=data['Hostel Fee'].fillna(data['Hostel Fee'].median())

# %%
data["Intermediate Percentage"]
# Out:
# 0      Above 90
# 1            80
# 2            80
# 3            80
# 4      Above 90
#          ...
# 96           60
# 97           60
# 98           80
# 99           60
# 100          70
# Name: Intermediate Percentage, Length: 101, dtype: object

# %%
data=data.replace({'Intermediate Percentage':{"Above 90":np.random.randint(90,99),80:80,70:70,60:60,50:50}})

# %%
data.isnull().sum()
# Out:
# Student ID                                                      0
# Timestamp                                                       0
# Student Name                                                    0
# University Name                                                 0
# NIRF Rank of University                                         0
# Minimum Percentage to get the University seat                   0
# Intermediate Percentage                                         0
# Eamcet Rank                                                     0
# University Fee                                                  0
# How are the placements Available                                0
# Rating for your University                                      0
# Do Your University is having Extra curricular Activity          0
# Do Your University is having Industry Evaluation Interaction    0
# Hostel Availability                                             0
# Hostel Fee                                                      0
# Hostel food Rating                                              0
# dtype: int64

# %%
data1=data

# %%
data1.head()
# Out:
#    Student ID               Timestamp         Student Name  \
# 0           1 2023-07-28 10:52:19.364              NIKHIL
# 1           2 2023-07-28 11:11:33.007  C SAI PRATHAP REDDY
# 2           3 2023-07-28 11:23:41.131                GOKUL
# 3           4 2023-07-28 11:25:29.124     K V SREE DHARANI
# 4           5 2023-07-28 11:25:58.998  KASUVU PRAVEENKUMAR
#
#                                    University Name  NIRF Rank of University  \
# 0  KALASALINGAM ACADEMY OF REASEARCH AND EDUCATION                       48
# 1  KALASALINGAM ACADEMY OF REASEARCH AND EDUCATION                       48
# 2                   SAVEETHA SCHOOL OF ENGINEERING                       27
# 3                            MOHAN BABU UNIVERSITY                      165
# 4             ANNAMACHARYA INSTITUTE OF TECHNOLOGY                       88
#
#    Minimum Percentage to get the University seat  Intermediate Percentage  \
# 0                                             80                       96
# 1                                             80                       80
# 2                                             70                       80
# 3                                             45                       80
# 4                                             70                       96
#
#    Eamcet Rank  University Fee How are the placements Available   \
# 0      24000.0           62500                              Good
# 1      27500.0          100000                              Good
# 2      27500.0          110000                              Good
# 3      50000.0          200000                              Good
# 4      90000.0           39000                              Good
#
#    Rating for your University  \
# 0                           4
# 1                           4
# 2                           4
# 3                           3
# 4                           1
#
#   Do Your University is having Extra curricular Activity   \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   Do Your University is having Industry Evaluation Interaction  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                 NO
# 4                                                YES
#
#   Hostel Availability  Hostel Fee  Hostel food Rating
# 0                 YES     71000.0                   3
# 1                 YES     65500.0                   4
# 2                 YES    110000.0                   5
# 3                 YES     70000.0                   3
# 4                 YES     78000.0                   2

# %% [markdown]
# # Exploratory Data Analysis and Visulization

# %%
sns.distplot(data['Minimum Percentage to get the University seat'])
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Minimum Percentage to get the University seat', ylabel='Density'>

# %%
sns.distplot(data['University Fee'])
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='University Fee', ylabel='Density'>

# %%
sns.distplot(data['Hostel Fee'])
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Hostel Fee', ylabel='Density'>

# %%
sns.distplot(data['Eamcet Rank'])
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Eamcet Rank', ylabel='Density'>

# %%
sns.distplot(data['Intermediate Percentage'])
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Intermediate Percentage', ylabel='Density'>

# %%
sns.countplot(data["How are the placements Available "])
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='How are the placements Available ', ylabel='count'>

# %%
sns.countplot(data["Do Your University is having Extra curricular Activity "])
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Do Your University is having Extra curricular Activity ', ylabel='count'>

# %%
sns.countplot(data["Do Your University is having Industry Evaluation Interaction"])
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Do Your University is having Industry Evaluation Interaction', ylabel='count'>

# %%
sns.countplot(data["Hostel Availability"])
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Hostel Availability', ylabel='count'>

# %%
sns.violinplot(data["NIRF Rank of University"]).set(title="violin plot")
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'violin plot')]

# %%
sns.pairplot(data=data)

# %%
sns.histplot(data["NIRF Rank of University"]).set(title="Histogram")
# Out:
# [Text(0.5, 1.0, 'Histogram')]

# %%
df=data

# %%
df.sample(5)
# Out:
#     Student ID               Timestamp         Student Name  \
# 84          85 2023-08-01 14:38:05.128           KALYAN RAM
# 7            8 2023-07-28 11:31:43.884      VALLURU GAFOOR
# 4            5 2023-07-28 11:25:58.998  KASUVU PRAVEENKUMAR
# 35          36 2023-07-28 19:51:53.977              TANMAI
# 14          15 2023-07-28 12:04:58.727      SHAIK NAGURVALI
#
#                                     University Name  NIRF Rank of University  \
# 84                                       IIT MADRAS                        1
# 7                                             JNTUA                       58
# 4              ANNAMACHARYA INSTITUTE OF TECHNOLOGY                       88
# 35                          RAYALASEEMA UNIVERSITY                       151
# 14  KALASALINGAM ACADEMY OF REASEARCH AND EDUCATION                       48
#
#     Minimum Percentage to get the University seat  Intermediate Percentage  \
# 84                                             85                       96
# 7                                              60                       80
# 4                                              70                       96
# 35                                             55                       96
# 14                                             80                       80
#
#     Eamcet Rank  University Fee How are the placements Available   \
# 84       1200.0               0                              Good
# 7       55000.0           55000                              Good
# 4       90000.0           39000                              Good
# 35       6000.0           75000                              Good
# 14      80000.0           95000                           Average
#
#     Rating for your University  \
# 84                           5
# 7                            3
# 4                            1
# 35                           5
# 14                           3
#
#    Do Your University is having Extra curricular Activity   \
# 84                                                YES
# 7                                                 YES
# 4                                                 YES
# 35                                                YES
# 14                                                YES
#
#    Do Your University is having Industry Evaluation Interaction  \
# 84                                                YES
# 7                                                 YES
# 4                                                 YES
# 35                                                YES
# 14                                                YES
#
#    Hostel Availability  Hostel Fee  Hostel food Rating
# 84                 YES    100000.0                   4
# 7                  YES    100000.0                   3
# 4                  YES     78000.0                   2
# 35                 YES     60000.0                   4
# 14                 YES     80000.0                   1

# %% [markdown]
# # Log Transformation

# %%
data['Minimum Percentage to get the University seat Log']=np.log(data['Minimum Percentage to get the University seat']+1)
sns.distplot(data['Minimum Percentage to get the University seat Log'])
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Minimum Percentage to get the University seat Log', ylabel='Density'>

# %%
data['University Fee Log']=np.log(data['University Fee']+1)
sns.distplot(data['University Fee Log'])
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='University Fee Log', ylabel='Density'>

# %%
data['Hostel Fee Log']=np.log(data['Hostel Fee']+1)
sns.distplot(data['Hostel Fee Log'])
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Hostel Fee Log', ylabel='Density'>

# %%
data['Eamcet Rank Log']=np.log(data['Eamcet Rank']+1)
sns.distplot(data['Eamcet Rank Log'])
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Eamcet Rank Log', ylabel='Density'>

# %%
data['Intermediate Percentage Log']=np.log(data['Intermediate Percentage']+1)
sns.distplot(data['Intermediate Percentage Log'])
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Intermediate Percentage Log', ylabel='Density'>

# %% [markdown]
# # Correlation Matrix

# %%
corr=df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
cols=['Student ID','Minimum Percentage to get the University seat','Timestamp','Student Name','University Name',
      'NIRF Rank of University','Rating for your University','Hostel food Rating',
      'Minimum Percentage to get the University seat Log']
df=df.drop(columns=cols)
df.sample(5)
# Out:
#     Intermediate Percentage  Eamcet Rank  University Fee  \
# 3                        80      50000.0          200000
# 70                       60      20000.0           45000
# 89                       80      16000.0           35000
# 77                       80      27500.0          125000
# 67                       96      31459.0          110000
#
#    How are the placements Available   \
# 3                               Good
# 70                              Good
# 89                              Good
# 77                           Average
# 67                              Good
#
#    Do Your University is having Extra curricular Activity   \
# 3                                                 YES
# 70                                                YES
# 89                                                YES
# 77                                                YES
# 67                                                YES
#
#    Do Your University is having Industry Evaluation Interaction  \
# 3                                                  NO
# 70                                                YES
# 89                                                YES
# 77                                                YES
# 67                                                 NO
#
#    Hostel Availability  Hostel Fee  University Fee Log  Hostel Fee Log  \
# 3                  YES     70000.0           12.206078       11.156265
# 70                 YES      5000.0           10.714440        8.517393
# 89                 YES     20000.0           10.463132        9.903538
# 77                 YES     60000.0           11.736077       11.002117
# 67                 YES    105000.0           11.608245       11.561725
#
#     Eamcet Rank Log  Intermediate Percentage Log
# 3         10.819798                     4.394449
# 70         9.903538                     4.110874
# 89         9.680406                     4.394449
# 77        10.221978                     4.394449
# 67        10.356472                     4.574711

# %% [markdown]
# # Label Encoding

# %%
cols=['How are the placements Available ','Do Your University is having Extra curricular Activity ',
      'Do Your University is having Industry Evaluation Interaction','Hostel Availability']
le=LabelEncoder()
for c in cols:
    df[c]=le.fit_transform(df[c])
df.sample(5)
# Out:
#     Intermediate Percentage  Eamcet Rank  University Fee  \
# 92                       80       4563.0          240000
# 54                       70      27500.0          300000
# 19                       96      27500.0          400000
# 79                       80      87000.0           15000
# 40                       70      80000.0           35000
#
#     How are the placements Available   \
# 92                                  0
# 54                                  2
# 19                                  2
# 79                                  0
# 40                                  0
#
#     Do Your University is having Extra curricular Activity   \
# 92                                                  1
# 54                                                  1
# 19                                                  1
# 79                                                  0
# 40                                                  1
#
#     Do Your University is having Industry Evaluation Interaction  \
# 92                                                  1
# 54                                                  0
# 19                                                  1
# 79                                                  0
# 40                                                  1
#
#     Hostel Availability  Hostel Fee  University Fee Log  Hostel Fee Log  \
# 92                    1    150000.0           12.388398       11.918397
# 54                    1    100000.0           12.611541       11.512935
# 19                    1    150000.0           12.899222       11.918397
# 79                    1     90000.0            9.615872       11.407576
# 40                    1     20000.0           10.463132        9.903538
#
#     Eamcet Rank Log  Intermediate Percentage Log
# 92         8.425955                     4.394449
# 54        10.221978                     4.262680
# 19        10.221978                     4.574711
# 79        11.373675                     4.394449
# 40        11.289794                     4.262680

# %%
X=df.drop(columns=['How are the placements Available '])
Y=df['How are the placements Available ']

# %% [markdown]
# # Train and Test Split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,shuffle=True,random_state=0,test_size=0.2)

# %% [markdown]
# # Train and Test Model

# %%
def model_Train(model,x,y):
    model.fit(x,y)
    yp=model.predict(x)
    from sklearn.metrics import confusion_matrix, accuracy_score,recall_score,f1_score,precision_score
    cm = confusion_matrix(y, yp)
    sns.heatmap(cm,annot=True)
    accuracy = accuracy_score(y,yp)*100
    print('Training Accuracy of our model is equal ' + str(round(accuracy, 2)) + ' %.')

    recall = recall_score(y,yp, labels=[1,2], average='micro')
    print('Train_Recall: %.3f' % recall)

    precision = precision_score(y,yp, labels=[1,2], average='micro')
    print('Train_Precision: %.3f' % precision)

    score = f1_score(y,yp, labels=[1,2], average='micro')
    print('Train_F1-Measure: %.3f' % score)

# %%
def model_Test(model,x,y_test):
  model = model
  model.fit(x,y_test)
  y_pred = model.predict(x)

  from sklearn.metrics import confusion_matrix, accuracy_score,recall_score,f1_score,precision_score
  cm = confusion_matrix(y_test, y_pred)
  sns.heatmap(cm,annot=True)

  accuracy = accuracy_score(y_test, y_pred)*100
  print('Testing Accuracy of our model is equal ' + str(round(accuracy, 2)) + ' %.')

  recall = recall_score(y_test, y_pred, labels=[1,2], average='micro')
  print('Recall: %.3f' % recall)

  precision = precision_score(y_test, y_pred, labels=[1,2], average='micro')
  print('Precision: %.3f' % precision)

  score = f1_score(y_test, y_pred, labels=[1,2], average='micro')
  print('F1-Measure: %.3f' % score)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=2000)
model_Train(model,x_train,y_train)
# Out:
# Training Accuracy of our model is equal 66.25 %.
# Train_Recall: 0.927
# Train_Precision: 0.671
# Train_F1-Measure: 0.779

# %%
model_Test(model,x_test,y_test)
# Out:
# Testing Accuracy of our model is equal 71.43 %.
# Recall: 0.765
# Precision: 0.722
# F1-Measure: 0.743

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=5)
model_Train(model,x_train,y_train)
# Out:
# Training Accuracy of our model is equal 75.0 %.
# Train_Recall: 0.873
# Train_Precision: 0.774
# Train_F1-Measure: 0.821

# %%
model_Test(model,x_test,y_test)
# Out:
# Testing Accuracy of our model is equal 71.43 %.
# Recall: 0.882
# Precision: 0.714
# F1-Measure: 0.789

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
model =ExtraTreesClassifier (n_estimators=1000, min_samples_split=25, max_depth=7, max_features=1)
model_Train(model,x_train,y_train)
# Out:
# Training Accuracy of our model is equal 71.25 %.
# Train_Recall: 0.945
# Train_Precision: 0.703
# Train_F1-Measure: 0.806

# %%
model_Test(model,x_test,y_test)
# Out:
# Testing Accuracy of our model is equal 71.43 %.
# Recall: 0.882
# Precision: 0.714
# F1-Measure: 0.789

# %%
model = RandomForestClassifier(n_estimators=1000, min_samples_split=25, max_depth=7, max_features=1)
model_Train(model,x_train,y_train)
# Out:
# Training Accuracy of our model is equal 75.0 %.
# Train_Recall: 0.945
# Train_Precision: 0.732
# Train_F1-Measure: 0.825

# %%
model_Test(model,x_test,y_test)
# Out:
# Testing Accuracy of our model is equal 71.43 %.
# Recall: 0.882
# Precision: 0.714
# F1-Measure: 0.789

# %%
p=model.predict(X)
df['Prediction on placements']=p

# %%
df
# Out:
#      Intermediate Percentage  Eamcet Rank  University Fee  \
# 0                         96      24000.0           62500
# 1                         80      27500.0          100000
# 2                         80      27500.0          110000
# 3                         80      50000.0          200000
# 4                         96      90000.0           39000
# ..                       ...          ...             ...
# 96                        60      20140.0          200000
# 97                        60      10000.0          100000
# 98                        80      70216.0          140000
# 99                        60      85000.0          100000
# 100                       70      27500.0           50000
#
#      How are the placements Available   \
# 0                                    2
# 1                                    2
# 2                                    2
# 3                                    2
# 4                                    2
# ..                                 ...
# 96                                   2
# 97                                   2
# 98                                   2
# 99                                   0
# 100                                  2
#
#      Do Your University is having Extra curricular Activity   \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 96                                                   1
# 97                                                   0
# 98                                                   0
# 99                                                   1
# 100                                                  1
#
#      Do Your University is having Industry Evaluation Interaction  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    0
# 4                                                    1
# ..                                                 ...
# 96                                                   0
# 97                                                   0
# 98                                                   0
# 99                                                   1
# 100                                                  1
#
#      Hostel Availability  Hostel Fee  University Fee Log  Hostel Fee Log  \
# 0                      1     71000.0           11.042938       11.170449
# 1                      1     65500.0           11.512935       11.089821
# 2                      1    110000.0           11.608245       11.608245
# 3                      1     70000.0           12.206078       11.156265
# 4                      1     78000.0           10.571343       11.264477
# ..                   ...         ...                 ...             ...
# 96                     1     50000.0           12.206078       10.819798
# 97                     1     50000.0           11.512935       10.819798
# 98                     1     80000.0           11.849405       11.289794
# 99                     1     85000.0           11.512935       11.350418
# 100                    1    100000.0           10.819798       11.512935
#
#      Eamcet Rank Log  Intermediate Percentage Log  Prediction on placements
# 0          10.085851                     4.574711                         2
# 1          10.221978                     4.394449                         2
# 2          10.221978                     4.394449                         2
# 3          10.819798                     4.394449                         2
# 4          11.407576                     4.574711                         2
# ..               ...                          ...                       ...
# 96          9.910513                     4.110874                         2
# 97          9.210440                     4.110874                         2
# 98         11.159346                     4.394449                         2
# 99         11.350418                     4.110874                         2
# 100        10.221978                     4.262680                         2
#
# [101 rows x 13 columns]

# %%
data['Prediction on placements']=p

# %%
data=data.replace({'Prediction on placements':{2:'Good',1:'Bad',0:'Average'}})

# %%
data.sample(5)
# Out:
#     Student ID               Timestamp      Student Name  \
# 26          27 2023-07-28 19:24:07.343    S CHITHRANJAN
# 97          98 2023-08-05 12:40:49.236              GURU
# 58          59 2023-07-28 22:37:32.760           BALAJI
# 45          46 2023-07-28 21:00:59.238       VAISHNAVI.C
# 46          47 2023-07-28 21:05:27.897  EDAGOTTU GANESH
#
#                                       University Name  \
# 26   NAGARJUNA  COLLEGE OF ENGINEERING AND TECHNOLOGY
# 97                              MOHAN BABU UNIVERSITY
# 58  SRI VENKATESWARA COLLEGE OF ENGINEERING AND TE...
# 45                        VISHWESHWARAIAH UNIVERSITY
# 46    MADANAPALLE INSTITUTE OF TECHNOLOGY AND SCIENCE
#
#     NIRF Rank of University  Minimum Percentage to get the University seat  \
# 26                      152                                             60
# 97                      165                                             45
# 58                      217                                             50
# 45                       52                                             75
# 46                      200                                             50
#
#     Intermediate Percentage  Eamcet Rank  University Fee  \
# 26                       80      13000.0          180000
# 97                       60      10000.0          100000
# 58                       80      27500.0          180000
# 45                       70      50000.0           90000
# 46                       80      27000.0           45000
#
#    How are the placements Available   ...  \
# 26                           Average  ...
# 97                              Good  ...
# 58                           Average  ...
# 45                              Good  ...
# 46                              Good  ...
#
#     Do Your University is having Industry Evaluation Interaction  \
# 26                                                YES
# 97                                                 NO
# 58                                                 NO
# 45                                                YES
# 46                                                YES
#
#    Hostel Availability Hostel Fee Hostel food Rating  \
# 26                 YES   110000.0                  3
# 97                 YES    50000.0                  4
# 58                 YES    70000.0                  3
# 45                 YES    80000.0                  3
# 46                 YES     5000.0                  5
#
#     Minimum Percentage to get the University seat Log  University Fee Log  \
# 26                                           4.110874           12.100718
# 97                                           3.828641           11.512935
# 58                                           3.931826           12.100718
# 45                                           4.330733           11.407576
# 46                                           3.931826           10.714440
#
#     Hostel Fee Log  Eamcet Rank Log  Intermediate Percentage Log  \
# 26       11.608245         9.472782                     4.394449
# 97       10.819798         9.210440                     4.110874
# 58       11.156265        10.221978                     4.394449
# 45       11.289794        10.819798                     4.262680
# 46        8.517393        10.203629                     4.394449
#
#     Prediction on placements
# 26                      Good
# 97                      Good
# 58                      Good
# 45                      Good
# 46                      Good
#
# [5 rows x 22 columns]

# %%
df.sample()
# Out:
#     Intermediate Percentage  Eamcet Rank  University Fee  \
# 23                       70      27500.0          140000
#
#     How are the placements Available   \
# 23                                  2
#
#     Do Your University is having Extra curricular Activity   \
# 23                                                  1
#
#     Do Your University is having Industry Evaluation Interaction  \
# 23                                                  1
#
#     Hostel Availability  Hostel Fee  University Fee Log  Hostel Fee Log  \
# 23                    1    100000.0           11.849405       11.512935
#
#     Eamcet Rank Log  Intermediate Percentage Log  Prediction on placements
# 23        10.221978                      4.26268                         2

# %%
I=int(input('Enter your Intermediate Percentage:'))
E=int(input('Enter your Eamcet Rank: [If not written enter 0] :'))
UF=int(input('Maximum Fee u can pay for university:'))
ECA=input('Do u need Extra curricular Activity-Yes/No:')
IE=input('Do u need Industry Evaluation Interaction-Yes/No:')
H=input('Reqired to stay in hostel-Yes/No:')
HF=int(input('Maximum Hostel Fee u can pay if hostel not required enter 0:'))
UFL=np.log(UF)
HFL=np.log(HF)
ERL=np.log(E)
IPL=np.log(I)
d1=pd.DataFrame({'Intermediate Percentage':[I],'Eamcet Rank':[E],'University Fee':[UF],'Extra curricular Activity':[ECA],
                 'Industry Evaluation':[IE],'Hostel required':[H],'Hostel Fee':[HF],'University Fee Log':[UFL],
                 'Hostel Fee Log':[HFL],'Eamcet Rank Log':[ERL],'Intermediate Percentage Log':[IPL]})
# Out:
# Enter your Intermediate Percentage:90
# Enter your Eamcet Rank: [If not written enter 0] :17000
# Maximum Fee u can pay for university:100000
# Do u need Extra curricular Activity-Yes/No:Yes
# Do u need Industry Evaluation Interaction-Yes/No:Yes
# Reqired to stay in hostel-Yes/No:Yes
# Maximum Hostel Fee u can pay if hostel not required enter 0:60000

# %%
d1
# Out:
#    Intermediate Percentage  Eamcet Rank  University Fee  \
# 0                       90        17000          100000
#
#   Extra curricular Activity Industry Evaluation Hostel required  Hostel Fee  \
# 0                       Yes                 Yes             Yes       60000
#
#    University Fee Log  Hostel Fee Log  Eamcet Rank Log  \
# 0           11.512925         11.0021         9.740969
#
#    Intermediate Percentage Log
# 0                      4.49981

# %%
from sklearn.preprocessing import LabelEncoder
cols=['Extra curricular Activity','Industry Evaluation','Hostel required']
le=LabelEncoder()
for c in cols:
    d1[c]=le.fit_transform(d1[c])
d1
# Out:
#    Intermediate Percentage  Eamcet Rank  University Fee  \
# 0                       90        17000          100000
#
#    Extra curricular Activity  Industry Evaluation  Hostel required  \
# 0                          0                    0                0
#
#    Hostel Fee  University Fee Log  Hostel Fee Log  Eamcet Rank Log  \
# 0       60000           11.512925         11.0021         9.740969
#
#    Intermediate Percentage Log
# 0                      4.49981

# %%
p=model.predict(d1)
d1['Prediction on placements']=p
# Out:
# C:\Users\venka\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Extra curricular Activity
# - Hostel required
# - Industry Evaluation
# Feature names seen at fit time, yet now missing:
# - Do Your University is having Extra curricular Activity
# - Do Your University is having Industry Evaluation Interaction
# - Hostel Availability
#
#   warnings.warn(message, FutureWarning)

# %%
u=[]
uf=[]
nirf=[]
mi=[]
r=[]
h=[]
hf=[]
hrf=[]
for i in range(101):
    if ((data1['Minimum Percentage to get the University seat'][i]<=I) & (data1['Eamcet Rank'][i]<=E)
        & (data1['University Fee'][i]<=UF) & (data1['Hostel Availability'][i]==H.upper()) & (data1['Hostel Fee'][i]<=HF)):
        u.append(data['University Name'][i])
        uf.append(data['University Fee'][i])
        nirf.append(data['NIRF Rank of University'][i])
        mi.append(data['Minimum Percentage to get the University seat'][i])
        r.append(data['Rating for your University'][i])
        h.append(data['Hostel Availability'][i])
        hf.append(data['Hostel Fee'][i])
        hrf.append(data['Hostel food Rating'][i])
d2=pd.DataFrame({'University Name':u,'University Fee':uf,
                'NIRF Rank of University':nirf,'Minimum Percentage to get the University seat': mi,
               'Rating for your University':r,'Hostel Availability':h
                 ,'Hostel Fee':hf
                ,'Hostel food Rating':hrf})

# %%
d2
# Out:
#                                    University Name  University Fee  \
# 0                    ACHARAYA NAGARJUNA UNIVERSITY           45000
# 1  KALASALINGAM ACADEMY OF REASEARCH AND EDUCATION           31250
# 2                          RAYALASEEMA UNIVERSITY            75000
# 3                          RAYALASEEMA UNIVERSITY            75000
# 4                    ACHARAYA NAGARJUNA UNIVERSITY           40000
# 5                    ACHARAYA NAGARJUNA UNIVERSITY           35000
# 6                            MOHAN BABU UNIVERSITY          100000
#
#    NIRF Rank of University  Minimum Percentage to get the University seat  \
# 0                       64                                             40
# 1                       48                                             80
# 2                      151                                             55
# 3                      151                                             55
# 4                       64                                             40
# 5                       64                                             40
# 6                      165                                             45
#
#    Rating for your University Hostel Availability  Hostel Fee  \
# 0                           4                 YES     15000.0
# 1                           4                 YES     55500.0
# 2                           5                 YES     60000.0
# 3                           5                 YES     60000.0
# 4                           4                 YES     20000.0
# 5                           5                 YES     20000.0
# 6                           4                 YES     50000.0
#
#    Hostel food Rating
# 0                   3
# 1                   2
# 2                   4
# 3                   4
# 4                   3
# 5                   1
# 6                   4

# %%
d1=d1.replace({'Prediction on placements':{2:'Good',1:'Bad',0:'Average'}})

# %%
d1
# Out:
#    Intermediate Percentage  Eamcet Rank  University Fee  \
# 0                       90        17000          100000
#
#    Extra curricular Activity  Industry Evaluation  Hostel required  \
# 0                          0                    0                0
#
#    Hostel Fee  University Fee Log  Hostel Fee Log  Eamcet Rank Log  \
# 0       60000           11.512925         11.0021         9.740969
#
#    Intermediate Percentage Log Prediction on placements
# 0                      4.49981                     Good

# %%
print("Your Placement with these details can be:",d1['Prediction on placements'])
# Out:
# Your Placement with these details can be: 0    Good
# Name: Prediction on placements, dtype: object
